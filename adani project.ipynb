# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import sys
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv("Adani data .csv")
data.head()
# Out:
#          Date    Open    High     Low   Close     Volume
# 0  12-08-2023  567.95  570.00  517.30  533.90  12,11,131
# 1  12-07-2023  569.90  574.95  552.10  562.05  26,40,229
# 2  12-06-2023  545.00  589.30  540.00  560.55  66,71,011
# 3  12-05-2023  464.80  545.85  454.75  538.50  51,43,120
# 4  12-04-2023  495.00  495.00  458.75  464.60  11,03,747

# %%
stock_data = data[['Date','Close']]
stock_data
# Out:
#           Date   Close
# 0   12-08-2023  533.90
# 1   12-07-2023  562.05
# 2   12-06-2023  560.55
# 3   12-05-2023  538.50
# 4   12-04-2023  464.60
# 5   12-01-2023  440.20
# 6   11/30/2023  431.30
# 7   11/29/2023  433.55
# 8   11/28/2023  445.80
# 9   11/24/2023  396.90
# 10  11/23/2023  381.65
# 11  11/22/2023  386.75
# 12  11/21/2023  392.45
# 13  11/20/2023  389.90
# 14  11/17/2023  387.40
# 15  11/16/2023  389.30
# 16  11/15/2023  390.60
# 17  11/13/2023  390.85
# 18  11-10-2023  399.10
# 19  11-09-2023  401.10
# 20  11-08-2023  393.45

# %%
stock_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    21 non-null     object
#  1   Close   21 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 464.0+ bytes

# %%
stock_data = stock_data.set_index('Date')

# %%
stock_data
# Out:
#              Close
# Date
# 12-08-2023  533.90
# 12-07-2023  562.05
# 12-06-2023  560.55
# 12-05-2023  538.50
# 12-04-2023  464.60
# 12-01-2023  440.20
# 11/30/2023  431.30
# 11/29/2023  433.55
# 11/28/2023  445.80
# 11/24/2023  396.90
# 11/23/2023  381.65
# 11/22/2023  386.75
# 11/21/2023  392.45
# 11/20/2023  389.90
# 11/17/2023  387.40
# 11/16/2023  389.30
# 11/15/2023  390.60
# 11/13/2023  390.85
# 11-10-2023  399.10
# 11-09-2023  401.10
# 11-08-2023  393.45

# %%
stock_data.describe()
# Out:
#             Close
# count   21.000000
# mean   433.804762
# std     61.771053
# min    381.650000
# 25%    390.600000
# 50%    399.100000
# 75%    445.800000
# max    562.050000

# %%
stock_data.head(10)
# Out:
#              Close
# Date
# 12-08-2023  533.90
# 12-07-2023  562.05
# 12-06-2023  560.55
# 12-05-2023  538.50
# 12-04-2023  464.60
# 12-01-2023  440.20
# 11/30/2023  431.30
# 11/29/2023  433.55
# 11/28/2023  445.80
# 11/24/2023  396.90

# %%
# Plot the Stock data
plt.plot(stock_data.Close)

# %%
# making this plot more readable :
# plot the close price
plt.style.use('ggplot')
plt.figure(figsize=(18,8))
plt.grid(True)
plt.xlabel('Dates', fontsize= (20))
plt.xticks(fontsize = 15)
plt.ylabel('Close prices', fontsize = 20)
plt.yticks(fontsize= 15)
plt.plot(stock_data['Close'], linewidth = 3, color = 'blue')

# %%
plt.hist(stock_data.Close)
# Out:
# (array([11.,  1.,  2.,  2.,  1.,  0.,  0.,  0.,  2.,  2.]),
#  array([381.65, 399.69, 417.73, 435.77, 453.81, 471.85, 489.89, 507.93,
#         525.97, 544.01, 562.05]),
#  <BarContainer object of 10 artists>)

# %%
# making histograme more readable
# plotting close price
plt.style.use('ggplot')
plt.figure(figsize=(18,8))
plt.grid(True)
plt.xlabel('Dates', fontsize = 20)
plt.xticks(fontsize = 15)
plt.ylabel('Close Prices', fontsize = 20)
plt.yticks(fontsize = 15)
plt.hist(stock_data['Close'], linewidth = 3, color = 'blue')
plt.title('Adani Power Stock Clossing Price', fontsize = 30)
plt.show()

# %%
# showing in displot aslo
import seaborn as sns
sns.distplot(stock_data.Close)
# Out:
# <AxesSubplot:xlabel='Close', ylabel='Density'>

# %%
# Distribution of the Close price
df_close = stock_data['Close']
df_close.plot(kind = 'kde',figsize = (18,8), linewidth= 3 )
plt.xticks(fontsize = 15)
plt.grid("both")
plt.ylabel('Density', fontsize = 20)
plt.yticks(fontsize = 15)
plt.show()
