# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
x=np.array([1,8,6,9,5,12])
plt.plot(x)

# %%
x=np.array([1,8,6,9,5,12])
plt.plot(x,marker="o",mec="r",markersize=30,ls="--",linewidth=10)

# %%
x=np.array([1,8,6,9,5,12])
plt.plot(x,marker="o",mec="r",markersize=30,ls="--",linewidth=10,color="#4CAF50")

# %%
x1=np.array([1,8,6,9,5,12])
x2=np.array([5,18,16,19,15,12])
plt.plot(x1,marker="o",mec="r",markersize=30,ls="--",linewidth=10,color="#4CAF50")
plt.plot(x2,marker="o",mec="g",markersize=30,ls="--",linewidth=10,color="hotpink")

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
plt.plot(x, y)
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.title("Calorie_Pulse graph",loc="left")
plt.grid(ls="--",lw=10,c="r",axis="y")
plt.show()
